# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "menotrainer")))

# %%
from langchain_groq import ChatGroq
from typing import List, Dict, Any
from config import Configuration
from pydantic import BaseModel, Field
from langchain_core.messages import HumanMessage
from services.api.app.agent.helpers import last_user_text
from services.api.app.agent.state import PhilosoferState   
from langchain_core.prompts import ChatPromptTemplate
from services.api.app.domain.prompts import (
    EXTRACT_EXERCISE_CARD
)
import numpy as np
from motor.motor_asyncio import AsyncIOMotorClient
#from services.api.app.agent.tools import retrieve_exercise_from_user_prompt

# %%
class ExerciseList(BaseModel):
    
    exercises: List[str] = Field(
        default_factory=list,
        description="Unique, canonical exercise names as strings. Empty list if none."
    )

# %%
def get_chat_model(
        temperature: float = Configuration.MODEL_TEMPERATURE,
        model: str = Configuration.MODEL_NAME
) -> ChatGroq:
    
    groq_model = ChatGroq(
        api_key=Configuration.GROQ_API_KEY,
        temperature=temperature,
        model=model
    )

    return groq_model

# %%
last_message = "I want to know what is the main target muscles for Squats and deadlifts, what is the difference between the two? what about hip thrust and hip thurst with dumbbells?" #already extract content through last_user_text function

chat_model = get_chat_model(
    temperature= 0.0, 
    model = Configuration.FAST_MODEL_NAME
    ).with_structured_output(ExerciseList)

prompt = ChatPromptTemplate.from_messages([
    ("system", EXTRACT_EXERCISE_CARD.prompt),
    ("human", last_message)
])      

response = await (prompt | chat_model).ainvoke({})
raw_list = response.exercises
unique_exercises = np.unique([ex.strip().lower() for ex in raw_list if ex.strip()])
    
print(unique_exercises)
# Out:
# ['deadlifts' 'hip thrust' 'hip thrust with dumbbells' 'squats']

# %%
from motor.motor_asyncio import AsyncIOMotorClient

# %%
async def fetch_target_muscles(unique_exercises: List[str]) -> Dict[str, Any]:
    
    MISSING = "No Data Found"
    mapping: Dict[str, str] = {ex: MISSING for ex in unique_exercises}

    if not unique_exercises:
        return mapping

    client = AsyncIOMotorClient(Configuration.mongo_uri)
    db = client[Configuration.MONGO_DB_NAME]
    coll = db[Configuration.MONGO_LONG_TERM_COLLECTION_EXERCISE]

    # Faster: one query with $in instead of looping
    # is basically a dictionary made out the collection in Mongo DB
    for ex in unique_exercises:
        print(ex)
        pipeline = [
            {"$search": {
                "index": 'exercise_serach_fuzzy',  # your Atlas Search index name
                "text": {
                    "path": "Exercise",
                    "query": ex,
                    "fuzzy": {
                        "maxEdits": 1,        # 0=exact only, 1–2 allow typos
                        "prefixLength": 1,    # first N chars must match exactly (helps precision)
                        "maxExpansions": 50
                    }
                }
            }},
            {"$project": {
                "_id": 0,
                "Exercise": 1,
                "Target Muscle Group ": 1,
                "score": {"$meta": "searchScore"}
            }},
            {"$limit": 1}
        ]

        docs = await coll.aggregate(pipeline).to_list(length=2)
        
        if docs:
            
            best = docs[0]
            mapping[ex] = best.get("Target Muscle Group ", MISSING)

    return mapping

# %%
docs = await fetch_target_muscles(['not an exercise','Single Arm Kettlebell bottoms Up Turkish Sit Up'])
# Out:
# not an exercise
# Single Arm Kettlebell bottoms Up Turkish Sit Up

# %%
docs
# Out:
# {'not an exercise': 'Abdominals',
#  'Single Arm Kettlebell bottoms Up Turkish Sit Up': 'Abdominals'}

# %%
async def test_mongo_connection():
    client = AsyncIOMotorClient(Configuration.mongo_uri)
    try:
        result = await client.admin.command('ping')
        print('MongoDB connection successful:', result)
    except Exception as e:
        print('MongoDB connection failed:', e)

await test_mongo_connection()
# Out:
# MongoDB connection successful: {'ok': 1}

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
async def fetch_collection_as_dataframe():
    client = AsyncIOMotorClient(Configuration.mongo_uri)
    db = client[Configuration.MONGO_DB_NAME]
    coll = db[Configuration.MONGO_LONG_TERM_COLLECTION_EXERCISE]
    cursor = coll.find({})
    docs = []
    async for doc in cursor:
        docs.append(doc)
    
    return docs

# %%
df = await fetch_collection_as_dataframe()

# %%
df
# Out:
# [{'_id': ObjectId('689ea38b9397f360c9dbdbb7'),
#   'Exercise': 'Bodyweight Glute Bridge',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Beginner',
#   'Target Muscle Group ': 'Glutes',
#   'Prime Mover Muscle': 'Gluteus Maximus',
#   'Secondary Muscle': 'Biceps Femoris',
#   'Tertiary Muscle': 'Erector Spinae',
#   'Primary Equipment ': 'Bodyweight',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Bridge',
#   'Single or Double Arm': 'No Arms',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'No Grip',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Hip Extension',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Lower Body',
#   'Force Type': 'Unsorted*',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdbc0'),
#   'Exercise': 'Bodyweight Dead Bug',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Beginner',
#   'Target Muscle Group ': 'Abdominals',
#   'Prime Mover Muscle': 'Rectus Abdominis',
#   'Secondary Muscle': 'Obliques',
#   'Tertiary Muscle': 'Rectus Femoris',
#   'Primary Equipment ': 'Bodyweight',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Supine',
#   'Single or Double Arm': 'Single Arm',
#   'Continuous or Alternating Arms ': 'Alternating',
#   'Grip': 'No Grip',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Alternating',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Anti-Extension',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Core',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Contralateral',
#   'Primary Exercise Classification': 'Postural'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdbc4'),
#   'Exercise': 'Bodyweight Seated Ab Circles',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Abdominals',
#   'Prime Mover Muscle': 'Rectus Abdominis',
#   'Primary Equipment ': 'Bodyweight',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Seated Floor',
#   'Single or Double Arm': 'No Arms',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Flat Palm',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Rotational',
#   'Plane Of Motion #1': 'Transverse Plane',
#   'Body Region': 'Core',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdbcb'),
#   'Exercise': 'Single Arm Dumbbell Side Plank Reach Through ',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Advanced',
#   'Target Muscle Group ': 'Abdominals',
#   'Prime Mover Muscle': 'Obliques',
#   'Secondary Muscle': 'Rectus Abdominis',
#   'Primary Equipment ': 'Dumbbell',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Side Plank',
#   'Single or Double Arm': 'Single Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Neutral',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Anti-Lateral Flexion',
#   'Movement Pattern #2': 'Spinal Rotational',
#   'Plane Of Motion #1': 'Transverse Plane',
#   'Body Region': 'Core',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdbcc'),
#   'Exercise': 'Ab Wheel Kneeling Rollout',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Abdominals',
#   'Prime Mover Muscle': 'Rectus Abdominis',
#   'Secondary Muscle': 'Latissimus Dorsi',
#   'Tertiary Muscle': 'Serratus Anterior',
#   'Primary Equipment ': 'Ab Wheel',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Kneeling',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Pronated',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Anti-Extension',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Core',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdbce'),
#   'Exercise': 'Cable Kneeling Crunch',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Abdominals',
#   'Prime Mover Muscle': 'Rectus Abdominis',
#   'Secondary Muscle': 'Iliopsoas',
#   'Tertiary Muscle': 'Obliques',
#   'Primary Equipment ': 'Cable',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Kneeling',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Neutral',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Spinal Flexion',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Core',
#   'Force Type': 'Other',
#   'Mechanics': 'Isolation',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdbd5'),
#   'Exercise': 'Stability Ball Knee Tuck',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Abdominals',
#   'Prime Mover Muscle': 'Rectus Abdominis',
#   'Primary Equipment ': 'Stability Ball',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Prone',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Flat Palm',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'Feet Elevated',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Spinal Flexion',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Core',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdbd6'),
#   'Exercise': 'Ring Hanging Leg Raise ',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Advanced',
#   'Target Muscle Group ': 'Abdominals',
#   'Prime Mover Muscle': 'Rectus Abdominis',
#   'Secondary Muscle': 'Iliopsoas',
#   'Tertiary Muscle': 'Obliques',
#   'Primary Equipment ': 'Gymnastic Rings',
#   '# Primary Items': 2,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Hanging',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Pronated',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Hip Flexion',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Core',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Calisthenics'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdbe8'),
#   'Exercise': 'Slider Double Kettlebell Bottoms Up Overhead Lateral Lunge',
#   'Difficulty Level': 'Advanced',
#   'Target Muscle Group ': 'Quadriceps',
#   'Prime Mover Muscle': 'Quadriceps Femoris',
#   'Secondary Muscle': 'Gluteus Maximus',
#   'Tertiary Muscle': 'Adductor Magnus',
#   'Primary Equipment ': 'Sliders',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'Kettlebell ',
#   '# Secondary Items': 2,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Bottoms Up',
#   'Load Position (Ending)': 'Overhead',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Knee Dominant',
#   'Plane Of Motion #1': 'Frontal Plane',
#   'Body Region': 'Lower Body',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdbf2'),
#   'Exercise': 'Bar Inverted Hanging Crunch',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Expert',
#   'Target Muscle Group ': 'Abdominals',
#   'Prime Mover Muscle': 'Rectus Abdominis',
#   'Secondary Muscle': 'Iliopsoas',
#   'Tertiary Muscle': 'Obliques',
#   'Primary Equipment ': 'Pull Up Bar',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Inverted ',
#   'Single or Double Arm': 'No Arms',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Head Supported',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Spinal Flexion',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Core',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdbf6'),
#   'Exercise': 'Bodyweight Supine Leg Raise',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Abdominals',
#   'Prime Mover Muscle': 'Rectus Abdominis',
#   'Secondary Muscle': 'Iliopsoas',
#   'Tertiary Muscle': 'Obliques',
#   'Primary Equipment ': 'Bodyweight',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Supine',
#   'Single or Double Arm': 'No Arms',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'No Grip',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Hip Flexion',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Core',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdbfb'),
#   'Exercise': 'Slider Mountain Climber',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Abdominals',
#   'Prime Mover Muscle': 'Rectus Abdominis',
#   'Secondary Muscle': 'Iliopsoas',
#   'Tertiary Muscle': 'Anterior Deltoids',
#   'Primary Equipment ': 'Sliders',
#   '# Primary Items': 2,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Prone',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Flat Palm',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Alternating',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Anti-Extension',
#   'Movement Pattern #2': 'Spinal Flexion',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Core',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdbfc'),
#   'Exercise': 'Slider Pike ',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Advanced',
#   'Target Muscle Group ': 'Abdominals',
#   'Prime Mover Muscle': 'Rectus Abdominis',
#   'Primary Equipment ': 'Sliders',
#   '# Primary Items': 2,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Prone',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Flat Palm',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Spinal Flexion',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Core',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdbfe'),
#   'Exercise': 'Slider Wide Mountain Climber',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Intermediate',
#   'Target Muscle Group ': 'Abdominals',
#   'Prime Mover Muscle': 'Rectus Abdominis',
#   'Secondary Muscle': 'Iliopsoas',
#   'Tertiary Muscle': 'Anterior Deltoids',
#   'Primary Equipment ': 'Sliders',
#   '# Primary Items': 2,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Prone',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Flat Palm',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Alternating',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Anti-Extension',
#   'Movement Pattern #2': 'Spinal Flexion',
#   'Plane Of Motion #1': 'Frontal Plane',
#   'Body Region': 'Core',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc07'),
#   'Exercise': 'Single Arm Dumbbell Side Plank',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Intermediate',
#   'Target Muscle Group ': 'Abdominals',
#   'Prime Mover Muscle': 'Obliques',
#   'Secondary Muscle': 'Rectus Abdominis',
#   'Primary Equipment ': 'Dumbbell',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Side Plank',
#   'Single or Double Arm': 'Single Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Neutral',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Anti-Lateral Flexion',
#   'Plane Of Motion #1': 'Frontal Plane',
#   'Body Region': 'Core',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc09'),
#   'Exercise': 'Dumbbell Glute Bridge',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Beginner',
#   'Target Muscle Group ': 'Glutes',
#   'Prime Mover Muscle': 'Gluteus Maximus',
#   'Secondary Muscle': 'Biceps Femoris',
#   'Tertiary Muscle': 'Erector Spinae',
#   'Primary Equipment ': 'Dumbbell',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Bridge',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Neutral',
#   'Load Position (Ending)': 'Hip Crease',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Hip Extension',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Lower Body',
#   'Force Type': 'Unsorted*',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc0c'),
#   'Exercise': 'Miniband Ankle Side Lying Hip Abduction',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Beginner',
#   'Target Muscle Group ': 'Abductors',
#   'Prime Mover Muscle': 'Gluteus Medius',
#   'Secondary Muscle': 'Gluteus Minimus',
#   'Tertiary Muscle': 'Tensor Fasciae Latae',
#   'Primary Equipment ': 'Miniband',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Side Lying',
#   'Single or Double Arm': 'No Arms',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'No Grip',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Hip Abduction',
#   'Plane Of Motion #1': 'Frontal Plane',
#   'Body Region': 'Lower Body',
#   'Force Type': 'Other',
#   'Mechanics': 'Isolation',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc10'),
#   'Exercise': 'Stability Ball Dumbbell Hip Thrust',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Beginner',
#   'Target Muscle Group ': 'Glutes',
#   'Prime Mover Muscle': 'Gluteus Maximus',
#   'Secondary Muscle': 'Biceps Femoris',
#   'Tertiary Muscle': 'Quadriceps Femoris',
#   'Primary Equipment ': 'Stability Ball',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'Dumbbell',
#   '# Secondary Items': 1,
#   'Posture': 'Bridge',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Neutral',
#   'Load Position (Ending)': 'Hip Crease',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Hip Extension',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Lower Body',
#   'Force Type': 'Unsorted*',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc11'),
#   'Exercise': 'Bodyweight Frog Pump',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Beginner',
#   'Target Muscle Group ': 'Glutes',
#   'Prime Mover Muscle': 'Gluteus Maximus',
#   'Secondary Muscle': 'Biceps Femoris',
#   'Tertiary Muscle': 'Adductor Magnus',
#   'Primary Equipment ': 'Bodyweight',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Bridge',
#   'Single or Double Arm': 'No Arms',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'No Grip',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Hip Extension',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Lower Body',
#   'Force Type': 'Unsorted*',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc14'),
#   'Exercise': 'Bodyweight Single Leg Foot Elevated Glute Bridge',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Glutes',
#   'Prime Mover Muscle': 'Gluteus Maximus',
#   'Secondary Muscle': 'Biceps Femoris',
#   'Tertiary Muscle': 'Obliques',
#   'Primary Equipment ': 'Bodyweight',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Single Leg Bridge',
#   'Single or Double Arm': 'No Arms',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'No Grip',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'Foot Elevated',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Hip Extension',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Lower Body',
#   'Force Type': 'Unsorted*',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc19'),
#   'Exercise': 'Miniband Standing Glute Kickback',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Glutes',
#   'Prime Mover Muscle': 'Gluteus Maximus',
#   'Primary Equipment ': 'Miniband',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'No Arms',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Hand Assisted',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Hip Extension',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Lower Body',
#   'Force Type': 'Unsorted*',
#   'Mechanics': 'Isolation',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc1c'),
#   'Exercise': 'Stability Ball Single Leg Foot Elevated Glute Bridge',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Intermediate',
#   'Target Muscle Group ': 'Glutes',
#   'Prime Mover Muscle': 'Gluteus Maximus',
#   'Secondary Muscle': 'Biceps Femoris',
#   'Tertiary Muscle': 'Obliques',
#   'Primary Equipment ': 'Stability Ball',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Single Leg Bridge',
#   'Single or Double Arm': 'No Arms',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'No Grip',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'Foot Elevated',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Hip Extension',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Lower Body',
#   'Force Type': 'Unsorted*',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc24'),
#   'Exercise': 'Barbell Shrug',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Trapezius',
#   'Prime Mover Muscle': 'Upper Trapezius',
#   'Secondary Muscle': 'Levator Scapulae',
#   'Tertiary Muscle': 'Rhomboids',
#   'Primary Equipment ': 'Barbell',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Pronated',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Scapular Elevation',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Isolation',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc25'),
#   'Exercise': 'Cable Face Pull',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Shoulders',
#   'Prime Mover Muscle': 'Posterior Deltoids',
#   'Secondary Muscle': 'Infraspinatus',
#   'Tertiary Muscle': 'Teres Minor',
#   'Primary Equipment ': 'Cable',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Neutral',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Shoulder External Rotation',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc2b'),
#   'Exercise': 'EZ Bar Spider Curl',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Biceps',
#   'Prime Mover Muscle': 'Biceps Brachii',
#   'Secondary Muscle': 'Brachialis',
#   'Tertiary Muscle': 'Brachioradialis',
#   'Primary Equipment ': 'EZ Bar',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'Bench (Incline)',
#   '# Secondary Items': 1,
#   'Posture': 'Prone',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Supinated',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Elbow Flexion',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Isolation',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc2c'),
#   'Exercise': 'Stability Ball Cable Preacher Curl',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Biceps',
#   'Prime Mover Muscle': 'Biceps Brachii',
#   'Secondary Muscle': 'Brachialis',
#   'Tertiary Muscle': 'Brachioradialis',
#   'Primary Equipment ': 'Stability Ball',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'Cable',
#   '# Secondary Items': 1,
#   'Posture': 'Prone',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Supinated',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Elbow Flexion',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Isolation',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc2d'),
#   'Exercise': 'Single Arm Dumbbell Standing Concentration Curl',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Biceps',
#   'Prime Mover Muscle': 'Biceps Brachii',
#   'Secondary Muscle': 'Brachialis',
#   'Tertiary Muscle': 'Brachioradialis',
#   'Primary Equipment ': 'Dumbbell',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Single Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Supinated',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Elbow Flexion',
#   'Plane Of Motion #1': 'Frontal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Isolation',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc2f'),
#   'Exercise': 'Single Arm Cable Standing High Bicep Curl',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Biceps',
#   'Prime Mover Muscle': 'Biceps Brachii',
#   'Secondary Muscle': 'Brachialis',
#   'Tertiary Muscle': 'Brachioradialis',
#   'Primary Equipment ': 'Cable',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Single Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Supinated',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Elbow Flexion',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Isolation',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc30'),
#   'Exercise': 'EZ Bar Seated Overhead Tricep Extension',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Triceps',
#   'Prime Mover Muscle': 'Triceps Brachii',
#   'Secondary Muscle': 'Anterior Deltoids',
#   'Tertiary Muscle': 'Rectus Abdominis',
#   'Primary Equipment ': 'EZ Bar',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'Bench (Flat)',
#   '# Secondary Items': 1,
#   'Posture': 'Seated',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Pronated',
#   'Load Position (Ending)': 'Overhead',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Elbow Extension',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Push',
#   'Mechanics': 'Isolation',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc35'),
#   'Exercise': 'Cable Rope Overhead Tricep Extension',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Triceps',
#   'Prime Mover Muscle': 'Triceps Brachii ',
#   'Secondary Muscle': 'Anterior Deltoids',
#   'Tertiary Muscle': 'Rectus Abdominis',
#   'Primary Equipment ': 'Cable',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Neutral',
#   'Load Position (Ending)': 'Overhead',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Elbow Extension',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Push',
#   'Mechanics': 'Isolation',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc40'),
#   'Exercise': 'Single Arm Dumbbell Overhead Carry',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Intermediate',
#   'Target Muscle Group ': 'Shoulders',
#   'Prime Mover Muscle': 'Anterior Deltoids',
#   'Secondary Muscle': 'Obliques',
#   'Primary Equipment ': 'Dumbbell',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Walking',
#   'Single or Double Arm': 'Single Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Neutral',
#   'Load Position (Ending)': 'Overhead',
#   'Continuous or Alternating Legs ': 'Alternating',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Loaded Carry',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Full Body',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc41'),
#   'Exercise': 'Double Dumbbell Pendlay Row',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Back',
#   'Prime Mover Muscle': 'Latissimus Dorsi',
#   'Primary Equipment ': 'Dumbbell',
#   '# Primary Items': 2,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Neutral',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Horizontal Pull',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc42'),
#   'Exercise': 'Cable Straight Bar Pullover',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Back',
#   'Prime Mover Muscle': 'Latissimus Dorsi',
#   'Primary Equipment ': 'Cable',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Pronated',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Horizontal Pull',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Isolation',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc44'),
#   'Exercise': 'Single Arm Cable Half Kneeling Low Row',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Back',
#   'Prime Mover Muscle': 'Latissimus Dorsi',
#   'Primary Equipment ': 'Cable',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Half Kneeling',
#   'Single or Double Arm': 'Single Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Neutral',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Horizontal Pull',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc47'),
#   'Exercise': 'Barbell Pendlay Row',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Back',
#   'Prime Mover Muscle': 'Latissimus Dorsi',
#   'Primary Equipment ': 'Barbell',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Pronated',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Horizontal Pull',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc49'),
#   'Exercise': 'Cable Single Leg Standing Bent Knee Hip External Rotation',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Glutes',
#   'Prime Mover Muscle': 'Gluteus Maximus',
#   'Secondary Muscle': 'Gluteus Medius',
#   'Tertiary Muscle': 'Gluteus Minimus',
#   'Primary Equipment ': 'Cable',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Single Leg Standing Bent Knee',
#   'Single or Double Arm': 'No Arms',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Hand Assisted',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Hip External Rotation',
#   'Plane Of Motion #1': 'Transverse Plane',
#   'Body Region': 'Lower Body',
#   'Force Type': 'Other',
#   'Mechanics': 'Isolation',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc4a'),
#   'Exercise': 'Cable Hip Rotation',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Glutes',
#   'Prime Mover Muscle': 'Gluteus Maximus',
#   'Secondary Muscle': 'Gluteus Medius',
#   'Tertiary Muscle': 'Gluteus Minimus',
#   'Primary Equipment ': 'Cable',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'No Arms',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Neutral',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Hip External Rotation',
#   'Plane Of Motion #1': 'Transverse Plane',
#   'Body Region': 'Lower Body',
#   'Force Type': 'Other',
#   'Mechanics': 'Isolation',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc4e'),
#   'Exercise': 'Barbell Bent Over Row',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Back',
#   'Prime Mover Muscle': 'Latissimus Dorsi',
#   'Secondary Muscle': 'Rhomboids',
#   'Tertiary Muscle': 'Posterior Deltoids',
#   'Primary Equipment ': 'Barbell',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Pronated',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Horizontal Pull',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc4f'),
#   'Exercise': 'Single Arm Landmine Meadows Row',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Back',
#   'Prime Mover Muscle': 'Latissimus Dorsi',
#   'Primary Equipment ': 'Landmine',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Single Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Pronated',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Horizontal Pull',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc54'),
#   'Exercise': 'Parallette Close Grip Push Up',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Triceps',
#   'Prime Mover Muscle': 'Triceps Brachii',
#   'Secondary Muscle': 'Pectoralis Major',
#   'Primary Equipment ': 'Parallette Bars',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Prone',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Pronated',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Horizontal Push',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Push',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Calisthenics'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc5b'),
#   'Exercise': 'Single Arm Cable Bicep Curl',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Biceps',
#   'Prime Mover Muscle': 'Biceps Brachii',
#   'Secondary Muscle': 'Brachialis',
#   'Tertiary Muscle': 'Brachioradialis',
#   'Primary Equipment ': 'Cable',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Single Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Supinated',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Elbow Flexion',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Isolation',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc5f'),
#   'Exercise': 'Single Arm Kettlebell Bent Over Row',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Back',
#   'Prime Mover Muscle': 'Latissimus Dorsi',
#   'Secondary Muscle': 'Rhomboids',
#   'Tertiary Muscle': 'Posterior Deltoids',
#   'Primary Equipment ': 'Kettlebell',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Single Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Neutral',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Horizontal Pull',
#   'Movement Pattern #2': 'Anti-Rotational ',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc69'),
#   'Exercise': 'Single Arm Kettlebell Push Jerk',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Shoulders',
#   'Prime Mover Muscle': 'Anterior Deltoids',
#   'Secondary Muscle': 'Triceps Brachii',
#   'Tertiary Muscle': 'Gluteus Minimus',
#   'Primary Equipment ': 'Kettlebell',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Single Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Pronated',
#   'Load Position (Ending)': 'Overhead',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Vertical Push',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Push',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc6e'),
#   'Exercise': 'Double Dumbbell Reverse Grip Bench Press',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Chest',
#   'Prime Mover Muscle': 'Pectoralis Major',
#   'Primary Equipment ': 'Dumbbell',
#   '# Primary Items': 2,
#   'Secondary Equipment': 'Bench (Flat)',
#   '# Secondary Items': 1,
#   'Posture': 'Supine',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Supinated',
#   'Load Position (Ending)': 'Above Chest',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Horizontal Push',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Push',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc6f'),
#   'Exercise': 'Single Arm Cable Seated Floor Lat Pulldown',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Back',
#   'Prime Mover Muscle': 'Latissimus Dorsi',
#   'Secondary Muscle': 'Biceps Brachii',
#   'Primary Equipment ': 'Cable',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Seated Floor',
#   'Single or Double Arm': 'Single Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Pronated',
#   'Load Position (Ending)': 'Overhead',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Vertical Pull',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc71'),
#   'Exercise': 'Single Arm Resistance Band Half Kneeling Cuban Press',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Shoulders',
#   'Prime Mover Muscle': 'Posterior Deltoids',
#   'Secondary Muscle': 'Infraspinatus',
#   'Tertiary Muscle': 'Upper Trapezius',
#   'Primary Equipment ': 'Resistance Band',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Half Kneeling',
#   'Single or Double Arm': 'Single Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Pronated',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Shoulder External Rotation',
#   'Movement Pattern #2': 'Vertical Push',
#   'Plane Of Motion #1': 'Transverse Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Push & Pull',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdc72'),
#   'Exercise': 'Double Dumbbell Cuban Press',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Shoulders',
#   'Prime Mover Muscle': 'Posterior Deltoids',
#   'Secondary Muscle': 'Infraspinatus',
#   'Tertiary Muscle': 'Upper Trapezius',
#   'Primary Equipment ': 'Dumbbell',
#   '# Primary Items': 2,
# ...
#   'Prime Mover Muscle': 'Posterior Deltoids',
#   'Primary Equipment ': 'Suspension Trainer',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Single Leg Standing Bent Knee',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Pronated',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Unsorted*',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Balance'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdf5a'),
#   'Exercise': 'Suspension Single Leg Standing Bent Knee Face Pull',
#   'Difficulty Level': 'Intermediate',
#   'Target Muscle Group ': 'Shoulders',
#   'Prime Mover Muscle': 'Posterior Deltoids',
#   'Secondary Muscle': 'Infraspinatus',
#   'Tertiary Muscle': 'Teres Minor',
#   'Primary Equipment ': 'Suspension Trainer',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Single Leg Standing Bent Knee',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Pronated',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Shoulder External Rotation',
#   'Plane Of Motion #1': 'Transverse Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Balance'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdf5b'),
#   'Exercise': 'Single Arm Kettlebell Half Kneeling Dead Clean',
#   'Difficulty Level': 'Intermediate',
#   'Target Muscle Group ': 'Glutes',
#   'Prime Mover Muscle': 'Gluteus Maximus',
#   'Secondary Muscle': 'Biceps Femoris',
#   'Tertiary Muscle': 'Rectus Abdominis',
#   'Primary Equipment ': 'Kettlebell',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Half Kneeling',
#   'Single or Double Arm': 'Single Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Neutral',
#   'Load Position (Ending)': 'Front Rack',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Hip Hinge',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Full Body',
#   'Force Type': 'Unsorted*',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Ballistics'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdf5e'),
#   'Exercise': 'Single Arm Kettlebell Half Kneeling Clean',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Intermediate',
#   'Target Muscle Group ': 'Glutes',
#   'Prime Mover Muscle': 'Gluteus Maximus',
#   'Primary Equipment ': 'Kettlebell',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Half Kneeling',
#   'Single or Double Arm': 'Single Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Neutral',
#   'Load Position (Ending)': 'Front Rack',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Hip Hinge',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Full Body',
#   'Force Type': 'Unsorted*',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Ballistics'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdf60'),
#   'Exercise': 'Double Kettlebell Front Rack Alternating Curtsy Lunge',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Quadriceps',
#   'Prime Mover Muscle': 'Quadriceps Femoris',
#   'Secondary Muscle': 'Gluteus Maximus',
#   'Tertiary Muscle': 'Adductor Magnus',
#   'Primary Equipment ': 'Kettlebell',
#   '# Primary Items': 2,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Neutral',
#   'Load Position (Ending)': 'Front Rack',
#   'Continuous or Alternating Legs ': 'Alternating',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Knee Dominant',
#   'Plane Of Motion #1': 'Frontal Plane',
#   'Body Region': 'Lower Body',
#   'Force Type': 'Push',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdf72'),
#   'Exercise': 'Single Arm Kettlebell Bottoms Up Otis Up',
#   'Difficulty Level': 'Intermediate',
#   'Target Muscle Group ': 'Abdominals',
#   'Prime Mover Muscle': 'Rectus Abdominis',
#   'Secondary Muscle': 'Iliopsoas',
#   'Tertiary Muscle': 'Obliques',
#   'Primary Equipment ': 'Kettlebell',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Supine',
#   'Single or Double Arm': 'Single Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Bottoms Up',
#   'Load Position (Ending)': 'Overhead',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Spinal Flexion',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Core',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdf73'),
#   'Exercise': 'Double Dumbbell Staggered Stance Romanian Deadlift',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Hamstrings',
#   'Prime Mover Muscle': 'Biceps Femoris',
#   'Secondary Muscle': 'Gluteus Maximus',
#   'Primary Equipment ': 'Dumbbell',
#   '# Primary Items': 2,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Staggered Stance',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Pronated',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Hip Hinge',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Lower Body',
#   'Force Type': 'Pull',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdf75'),
#   'Exercise': 'Single Arm Kettlebell Bottoms Up Turkish Sit Up',
#   'Difficulty Level': 'Intermediate',
#   'Target Muscle Group ': 'Abdominals',
#   'Prime Mover Muscle': 'Rectus Abdominis',
#   'Secondary Muscle': 'Anterior Deltoids',
#   'Tertiary Muscle': 'Iliopsoas',
#   'Primary Equipment ': 'Kettlebell',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Supine',
#   'Single or Double Arm': 'Single Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Bottoms Up',
#   'Load Position (Ending)': 'Overhead',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Spinal Flexion',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Core',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdf80'),
#   'Exercise': 'Double Kettlebell Bottoms Up Front Rack Low Switch Cossack Squat',
#   'Difficulty Level': 'Advanced',
#   'Target Muscle Group ': 'Quadriceps',
#   'Prime Mover Muscle': 'Quadriceps Femoris',
#   'Secondary Muscle': 'Adductor Magnus',
#   'Tertiary Muscle': 'Gluteus Maximus',
#   'Primary Equipment ': 'Kettlebell',
#   '# Primary Items': 2,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Bottoms Up',
#   'Load Position (Ending)': 'Front Rack',
#   'Continuous or Alternating Legs ': 'Alternating',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Knee Dominant',
#   'Plane Of Motion #1': 'Frontal Plane',
#   'Body Region': 'Lower Body',
#   'Force Type': 'Push',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdf84'),
#   'Exercise': 'Double Kettlebell Bottoms Up Dead Clean to Overhead Press',
#   'Difficulty Level': 'Intermediate',
#   'Target Muscle Group ': 'Shoulders',
#   'Prime Mover Muscle': 'Anterior Deltoids',
#   'Secondary Muscle': 'Gluteus Maximus',
#   'Primary Equipment ': 'Kettlebell',
#   '# Primary Items': 2,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Bottoms Up',
#   'Load Position (Ending)': 'Overhead',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Combo Exercise',
#   'Movement Pattern #1': 'Vertical Push',
#   'Movement Pattern #2': 'Hip Hinge',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Full Body',
#   'Force Type': 'Unsorted*',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdf86'),
#   'Exercise': 'Bodyweight Foot Elevated Cossack Squat',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Beginner',
#   'Target Muscle Group ': 'Quadriceps',
#   'Prime Mover Muscle': 'Quadriceps Femoris',
#   'Secondary Muscle': 'Adductor Magnus',
#   'Tertiary Muscle': 'Gluteus Maximus',
#   'Primary Equipment ': 'Bodyweight',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'No Arms',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'No Grip',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'Foot Elevated (Lateral)',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Knee Dominant',
#   'Plane Of Motion #1': 'Frontal Plane',
#   'Body Region': 'Lower Body',
#   'Force Type': 'Push',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Bodybuilding'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdf8d'),
#   'Exercise': 'Double Kettlebell Windmill',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Advanced',
#   'Target Muscle Group ': 'Abdominals',
#   'Prime Mover Muscle': 'Obliques',
#   'Secondary Muscle': 'Rectus Abdominis',
#   'Tertiary Muscle': 'Anterior Deltoids',
#   'Primary Equipment ': 'Kettlebell',
#   '# Primary Items': 2,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Neutral',
#   'Load Position (Ending)': 'Overhead',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Rotational',
#   'Plane Of Motion #1': 'Transverse Plane',
#   'Body Region': 'Core',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Grinds'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdf8f'),
#   'Exercise': 'Barbell Staggered Stance Overhead Press',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Intermediate',
#   'Target Muscle Group ': 'Shoulders',
#   'Prime Mover Muscle': 'Anterior Deltoids',
#   'Secondary Muscle': 'Triceps Brachii',
#   'Primary Equipment ': 'Barbell',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Staggered Stance',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Pronated',
#   'Load Position (Ending)': 'Overhead',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Vertical Push',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Push',
#   'Mechanics': 'Compound',
#   'Laterality': 'Bilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdf91'),
#   'Exercise': 'Kettlebell Dead Bug',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Abdominals',
#   'Prime Mover Muscle': 'Rectus Abdominis',
#   'Secondary Muscle': 'Obliques',
#   'Tertiary Muscle': 'Rectus Femoris',
#   'Primary Equipment ': 'Kettlebell',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Supine',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'Goblet',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Alternating',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Anti-Extension',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Core',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Postural'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdf94'),
#   'Exercise': 'Superband Lateral Step Hip Adduction',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'Difficulty Level': 'Novice',
#   'Target Muscle Group ': 'Adductors',
#   'Prime Mover Muscle': 'Adductor Magnus',
#   'Primary Equipment ': 'Superband',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Standing',
#   'Single or Double Arm': 'No Arms',
#   'Continuous or Alternating Arms ': 'Continuous',
#   'Grip': 'No Grip',
#   'Load Position (Ending)': 'No Load',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Hip Adduction',
#   'Plane Of Motion #1': 'Frontal Plane',
#   'Body Region': 'Lower Body',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Unsorted*'},
#  {'_id': ObjectId('689ea38b9397f360c9dbdf9a'),
#   'Exercise': 'Battle Rope Single Leg Standing Alternating Wave',
#   'Short YouTube Demonstration': 'Video Demonstration',
#   'In-Depth YouTube Explanation': 'Video Explanation',
#   'Difficulty Level': 'Intermediate',
#   'Target Muscle Group ': 'Biceps',
#   'Prime Mover Muscle': 'Biceps Brachii',
#   'Primary Equipment ': 'Battle Ropes',
#   '# Primary Items': 1,
#   'Secondary Equipment': 'None',
#   '# Secondary Items': 0,
#   'Posture': 'Single Leg Standing',
#   'Single or Double Arm': 'Double Arm',
#   'Continuous or Alternating Arms ': 'Alternating',
#   'Grip': 'Neutral',
#   'Load Position (Ending)': 'Other',
#   'Continuous or Alternating Legs ': 'Continuous',
#   'Foot Elevation': 'No Elevation',
#   'Combination Exercises': 'Single Exercise',
#   'Movement Pattern #1': 'Unsorted*',
#   'Plane Of Motion #1': 'Sagittal Plane',
#   'Body Region': 'Upper Body',
#   'Force Type': 'Other',
#   'Mechanics': 'Compound',
#   'Laterality': 'Unilateral',
#   'Primary Exercise Classification': 'Balance'},
#  ...]

# %% [markdown]
# # Testing Nodes / Edges

# %%
import sys
import os

# Add the parent directory to sys.path so 'menotrainer' is discoverable
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

# %%
from services.api.app.agent.state import PhilosoferState
from services.api.app.agent.chains import get_trainer_chain
from services.api.app.agent.nodes import conversation_node
from services.api.app.agent.edges import should_retrieve_exercise_content
from services.api.app.agent.chains import get_trainer_chain

from langchain_core.messages import HumanMessage
from langchain_core.messages import SystemMessage
from langchain_core.runnables import RunnableConfig
from langgraph.graph import MessagesState

# %% [markdown]
# ## conversation node

# %%
state = PhilosoferState()

# %%
response = await conversation_node(state = state, config = RunnableConfig)
state["messages"] = response.get("messages", [])
state["messages"]
#conversation_chain  = get_trainer_chain()
# Out:
# [AIMessage(content="Welcome to our fitness journey together. I'm excited to help you achieve your health and wellness goals. What's on your mind today? Are you looking to create a personalized meal plan, design a workout routine, or perhaps discuss strategies for staying motivated and accountable? Let's get started and make progress towards a healthier, happier you. What's your first question or area of focus?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 277, 'total_tokens': 354, 'completion_time': 0.212058144, 'prompt_time': 0.0442249, 'queue_time': 0.212557248, 'total_time': 0.256283044}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_6507bcfb6f', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--af492155-8132-449b-ba8b-8005bf73681d-0', usage_metadata={'input_tokens': 277, 'output_tokens': 77, 'total_tokens': 354})]

# %%
hm = HumanMessage(content="are deadlifts safe?")
msgs = state.get("messages", [])

# %%
msgs.append(hm)
state["messages"] = msgs

# %%
state.get("messages", [])
# Out:
# [AIMessage(content="Welcome to our fitness journey together. I'm excited to help you achieve your health and wellness goals. What's on your mind today? Are you looking to create a personalized meal plan, design a workout routine, or perhaps discuss strategies for staying motivated and accountable? Let's get started and make progress towards a healthier, happier you. What's your first question or area of focus?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 277, 'total_tokens': 354, 'completion_time': 0.212058144, 'prompt_time': 0.0442249, 'queue_time': 0.212557248, 'total_time': 0.256283044}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_6507bcfb6f', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--af492155-8132-449b-ba8b-8005bf73681d-0', usage_metadata={'input_tokens': 277, 'output_tokens': 77, 'total_tokens': 354}),
#  HumanMessage(content='are deadlifts safe?', additional_kwargs={}, response_metadata={})]

# %%
response = await conversation_node(state = state, config = RunnableConfig)
response
# Out:
# {'messages': [AIMessage(content="Deadlifts can be a safe and effective exercise when performed properly. However, like any exercise, they do come with some risk of injury, particularly to the lower back. The key to safe deadlifting is to use proper form and technique.\n\nTo minimize the risk of injury, it's essential to:\n\n1. **Start with a manageable weight**: Don't try to lift too much too soon. Gradually increase the weight as you build strength and confidence.\n2. **Maintain proper form**: Keep your back straight, engage your core, and lift with your legs and hips, rather than just your back.\n3. **Use a full range of motion**: Lift the weight from the floor to hip level, squeezing your glutes and pushing your hips back at the top of the movement.\n4. **Avoid rounding your back**: Keep your chest up and your shoulders down, avoiding any curvature of the spine.\n5. **Warm up and cool down**: Always warm up before deadlifting, and cool down afterwards to prevent muscle strain.\n\nSome common injuries associated with deadlifts include:\n\n* Lower back strain\n* Herniated discs\n* Knee injuries (from improper form or overuse)\n\nTo mitigate these risks, consider the following:\n\n* **Work with a personal trainer or experienced lifter** to learn proper form and technique.\n* **Incorporate exercises that strengthen your core and back muscles**, such as planks, rows, and lat pulldowns.\n* **Listen to your body**: If you experience any pain or discomfort, stop the exercise immediately and consult with a medical professional.\n\nRemember, deadlifts can be a valuable addition to a well-rounded workout routine, but safety should always be your top priority. Do you have any experience with deadlifts, or is this a new exercise you're considering adding to your routine?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 371, 'prompt_tokens': 369, 'total_tokens': 740, 'completion_time': 0.895585517, 'prompt_time': 0.035087985, 'queue_time': 0.225591931, 'total_time': 0.930673502}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_6507bcfb6f', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--ea15c0ba-d3ce-4d9f-b8d9-ad7f22fbee5d-0', usage_metadata={'input_tokens': 369, 'output_tokens': 371, 'total_tokens': 740})]}

# %%
print(response['messages'][0].content)
# Out:
# Deadlifts can be a safe and effective exercise when performed properly. However, like any exercise, they do come with some risk of injury, particularly to the lower back. The key to safe deadlifting is to use proper form and technique.
#
# To minimize the risk of injury, it's essential to:
#
# 1. **Start with a manageable weight**: Don't try to lift too much too soon. Gradually increase the weight as you build strength and confidence.
# 2. **Maintain proper form**: Keep your back straight, engage your core, and lift with your legs and hips, rather than just your back.
# 3. **Use a full range of motion**: Lift the weight from the floor to hip level, squeezing your glutes and pushing your hips back at the top of the movement.
# 4. **Avoid rounding your back**: Keep your chest up and your shoulders down, avoiding any curvature of the spine.
# 5. **Warm up and cool down**: Always warm up before deadlifting, and cool down afterwards to prevent muscle strain.
#
# Some common injuries associated with deadlifts include:
#
# * Lower back strain
# * Herniated discs
# * Knee injuries (from improper form or overuse)
#
# To mitigate these risks, consider the following:
#
# * **Work with a personal trainer or experienced lifter** to learn proper form and technique.
# * **Incorporate exercises that strengthen your core and back muscles**, such as planks, rows, and lat pulldowns.
# * **Listen to your body**: If you experience any pain or discomfort, stop the exercise immediately and consult with a medical professional.
#
# Remember, deadlifts can be a valuable addition to a well-rounded workout routine, but safety should always be your top priority. Do you have any experience with deadlifts, or is this a new exercise you're considering adding to your routine?

# %% [markdown]
# ## Should retrieve conditional function

# %%
state = PhilosoferState()
hm = HumanMessage(content="are deadlifts safe?")
msgs = state.get("messages", [])
msgs.append(hm)
state["messages"] = msgs

# %%
 state.get("messages", [])
# Out:
# [HumanMessage(content='are deadlifts safe?', additional_kwargs={}, response_metadata={})]

# %%
await should_retrieve_exercise_content(state)
# Out:
# False

# %%
state = PhilosoferState()

# create a human message
hm = HumanMessage(content="What muscles do squats target?")

# append safely to the messages list and write back into the state
msgs = state.get("messages", [])
msgs.append(hm)
state["messages"] = msgs   # or state.update({"messages": msgs}) if you prefer

# verify
last = state.get("messages", [])[-1]
print(type(last), last.content)
# Out:
# <class 'langchain_core.messages.human.HumanMessage'> What muscles do squats target?

# %%
# create a human message
system = SystemMessage(content="Quadriceps!")

# append safely to the messages list and write back into the state
msgs = state.get("messages", [])
msgs.append(system)
state["messages"] = msgs   # or state.update({"messages": msgs}) if you prefer

# verify
last = state.get("messages", [])[-1]
print(type(last), last.content)
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> Quadriceps!

# %%
await conversation_node(state = state, config = RunnableConfig)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 await conversation_node(state = state, config = RunnableConfig)
#
# File c:\Users\mario\rag_project\menotrainer\services\api\app\agent\nodes.py:28, in conversation_node(state, config)
#      26 messages = state.get("messages", [])
#      27 summary = state.get("summary", "")
# ---> 28 exercise_data = state.get_exercises_summary()
#      30 conversation_chain = get_trainer_chain()
#      32 response = await conversation_chain.ainvoke(
#      33     {
#      34         "messages": messages,
#    (...)     38     }
#      39 )
#
# AttributeError: 'dict' object has no attribute 'get_exercises_summary'

# %%
state.get("messages", [])
type(state.get("messages", []))
# Out:
# list

# %%
type(state.get('messages',[]))
# Out:
# list

# %%
state = PhilosoferState()
state["messages"] = ['HI!']

# %%
exercise_data = state.get("exercises_data", {
    "exercises_user_ask_about": [],
    "main_muscle_target": []
})

# %%
exercise_data
# Out:
# {'exercises_user_ask_about': ['test 1', 'test 3'],
#  'main_muscle_target': ['test 2', 'test 4']}

# %%
exercise_data['exercises_user_ask_about'].append('test 5')
exercise_data['main_muscle_target'].append('test 6')

# %%
state['exercises_data'] = exercise_data

# %%
state['exercises_data']
# Out:
# {'exercises_user_ask_about': ['test 1', 'test 3', 'test 5'],
#  'main_muscle_target': ['test 2', 'test 4', 'test 6']}

# %%
if 'exercises_data' not in state:
    state['exercises_data'] = {
        "exercises_user_ask_about": ['test 1'],
        "main_muscle_target": ['test 2']
    }
else:
    state['exercises_data']['exercises_user_ask_about'].append('test 3')
    state['exercises_data']['main_muscle_target'].append('test 4')
# Out:
# {'messages': ['HI!']}

# %%
state['messages'].append('Hello again!')

# %%
state['exercises_data'] = {
        "exercises_user_ask_about": ['test 1'],
        "main_muscle_target": ['test 2']
}

# %%
state
# Out:
# {'messages': ['HI!', 'Hello again!'],
#  'exercises_data': {'exercises_user_ask_about': ['test 1'],
#   'main_muscle_target': ['test 2']}}
